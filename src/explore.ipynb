# %% [markdown]
# # Explore here

# %%
# Your code here

import pandas as pd

df = pd.read_csv('https://breathecode.herokuapp.com/asset/internal-link?id=2546&path=sales.csv')
df
# Out:
#                            date        sales
# 0    2022-09-03 17:10:08.079328    55.292157
# 1    2022-09-04 17:10:08.079328    53.803211
# 2    2022-09-05 17:10:08.079328    58.141693
# 3    2022-09-06 17:10:08.079328    64.530899
# 4    2022-09-07 17:10:08.079328    66.013633
# ..                          ...          ...
# 361  2023-08-30 17:10:08.079328   989.600354
# 362  2023-08-31 17:10:08.079328   994.987326
# 363  2023-09-01 17:10:08.079328   995.814415
# 364  2023-09-02 17:10:08.079328   997.350214
# 365  2023-09-03 17:10:08.079328  1000.482785
#
# [366 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    366 non-null    str
#  1   sales   366 non-null    float64
# dtypes: float64(1), str(1)
# memory usage: 5.8 KB

# %%
df['date'] = pd.to_datetime(df['date'])
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    366 non-null    datetime64[us]
#  1   sales   366 non-null    float64
# dtypes: datetime64[us](1), float64(1)
# memory usage: 5.8 KB

# %%
df = df.set_index('date')
df.head()
# Out:
#                                 sales
# date
# 2022-09-03 17:10:08.079328  55.292157
# 2022-09-04 17:10:08.079328  53.803211
# 2022-09-05 17:10:08.079328  58.141693
# 2022-09-06 17:10:08.079328  64.530899
# 2022-09-07 17:10:08.079328  66.013633

# %%
import matplotlib.pyplot as plt

plt.plot(df)
plt.show()

# %%
# !pip install statsmodels
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: statsmodels in /home/vscode/.local/lib/python3.11/site-packages (0.14.6)
# Requirement already satisfied: numpy<3,>=1.22.3 in /home/vscode/.local/lib/python3.11/site-packages (from statsmodels) (2.4.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /home/vscode/.local/lib/python3.11/site-packages (from statsmodels) (1.17.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /home/vscode/.local/lib/python3.11/site-packages (from statsmodels) (3.0.1)
# Requirement already satisfied: patsy>=0.5.6 in /home/vscode/.local/lib/python3.11/site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in /home/vscode/.local/lib/python3.11/site-packages (from statsmodels) (26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vscode/.local/lib/python3.11/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/vscode/.local/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
#
# [notice] A new release of pip is available: 23.1.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

seasonal = seasonal_decompose(df, period = 7)

trend = seasonal.trend
estacionalidad = seasonal.seasonal
error = seasonal.resid

plt.plot(trend)
plt.plot(estacionalidad)
plt.plot(error, color = 'purple')

# %%
df_train = df[df.index <= '2023-08-01']
df_test = df[df.index >= '2023-08-01']

# %%
# !pip install pmdarima
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pmdarima in /home/vscode/.local/lib/python3.11/site-packages (2.1.1)
# Requirement already satisfied: joblib>=0.11 in /home/vscode/.local/lib/python3.11/site-packages (from pmdarima) (1.5.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /home/vscode/.local/lib/python3.11/site-packages (from pmdarima) (3.2.4)
# Requirement already satisfied: numpy>=1.21.6 in /home/vscode/.local/lib/python3.11/site-packages (from pmdarima) (2.4.2)
# Requirement already satisfied: pandas>=0.19 in /home/vscode/.local/lib/python3.11/site-packages (from pmdarima) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.22 in /home/vscode/.local/lib/python3.11/site-packages (from pmdarima) (1.8.0)
# Requirement already satisfied: scipy>=1.13.0 in /home/vscode/.local/lib/python3.11/site-packages (from pmdarima) (1.17.1)
# Requirement already satisfied: statsmodels>=0.14.5 in /home/vscode/.local/lib/python3.11/site-packages (from pmdarima) (0.14.6)
# Requirement already satisfied: urllib3 in /home/vscode/.local/lib/python3.11/site-packages (from pmdarima) (2.6.3)
# Requirement already satisfied: setuptools!=50.0.0,>=42 in /usr/local/lib/python3.11/site-packages (from pmdarima) (67.8.0)
# Requirement already satisfied: packaging>=17.1 in /home/vscode/.local/lib/python3.11/site-packages (from pmdarima) (26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vscode/.local/lib/python3.11/site-packages (from pandas>=0.19->pmdarima) (2.9.0.post0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from scikit-learn>=0.22->pmdarima) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /home/vscode/.local/lib/python3.11/site-packages (from statsmodels>=0.14.5->pmdarima) (1.0.2)
# Requirement already satisfied: six>=1.5 in /home/vscode/.local/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=0.19->pmdarima) (1.17.0)
#
# [notice] A new release of pip is available: 23.1.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
from pmdarima import auto_arima

model = auto_arima(df_train, seasonal = False, trace = True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=1673.403, Time=0.46 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1904.573, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1792.947, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1670.865, Time=0.19 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=2005.236, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1670.214, Time=0.14 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=1672.117, Time=0.30 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=1674.856, Time=0.11 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=1670.139, Time=0.13 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=1672.113, Time=0.14 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.37 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=1966.589, Time=0.04 sec
#
# Best model:  ARIMA(0,1,2)(0,0,0)[0] intercept
# Total fit time: 1.977 seconds

# %%
sales_pred = model.predict(34)
sales_pred
# Out:
# 2023-08-01 17:10:08.079328    914.086751
# 2023-08-02 17:10:08.079328    916.379149
# 2023-08-03 17:10:08.079328    918.975976
# 2023-08-04 17:10:08.079328    921.572804
# 2023-08-05 17:10:08.079328    924.169632
# 2023-08-06 17:10:08.079328    926.766459
# 2023-08-07 17:10:08.079328    929.363287
# 2023-08-08 17:10:08.079328    931.960115
# 2023-08-09 17:10:08.079328    934.556943
# 2023-08-10 17:10:08.079328    937.153770
# 2023-08-11 17:10:08.079328    939.750598
# 2023-08-12 17:10:08.079328    942.347426
# 2023-08-13 17:10:08.079328    944.944253
# 2023-08-14 17:10:08.079328    947.541081
# 2023-08-15 17:10:08.079328    950.137909
# 2023-08-16 17:10:08.079328    952.734736
# 2023-08-17 17:10:08.079328    955.331564
# 2023-08-18 17:10:08.079328    957.928392
# 2023-08-19 17:10:08.079328    960.525220
# 2023-08-20 17:10:08.079328    963.122047
# 2023-08-21 17:10:08.079328    965.718875
# 2023-08-22 17:10:08.079328    968.315703
# 2023-08-23 17:10:08.079328    970.912530
# 2023-08-24 17:10:08.079328    973.509358
# 2023-08-25 17:10:08.079328    976.106186
# 2023-08-26 17:10:08.079328    978.703013
# 2023-08-27 17:10:08.079328    981.299841
# 2023-08-28 17:10:08.079328    983.896669
# 2023-08-29 17:10:08.079328    986.493496
# 2023-08-30 17:10:08.079328    989.090324
# 2023-08-31 17:10:08.079328    991.687152
# 2023-09-01 17:10:08.079328    994.283980
# 2023-09-02 17:10:08.079328    996.880807
# 2023-09-03 17:10:08.079328    999.477635
# Freq: D, dtype: float64

# %%
plt.plot(df_test, color = 'red')
plt.plot(sales_pred, color = 'blue')

plt.show()

# %%
from sklearn.metrics import root_mean_squared_error,r2_score

error_2 = root_mean_squared_error(df_test,sales_pred)
r2 = r2_score(df_test, sales_pred)

print ( f' El Error cuadratico medio es de {error_2} y el R2 es de {r2}')
# Out:
#  El Error cuadratico medio es de 2.8347645458529587 y el R2 es de 0.9882747345147518

# %% [markdown]
# # Guardado del modelo

# %%
from pickle import dump

dump(model, open('../models/arima_0_1_2.pkl','wb'))
